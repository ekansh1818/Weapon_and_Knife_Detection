# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_db = pd.read_csv('./runs/detect/Db/results.csv')
df_db.columns = ['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss', "", "", ""]
df_db = df_db[['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss']]
df_db = df_db.iloc[:150, :]
df_db
# Out:
#      epoch  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1         1.50880         2.35390          1.7305
# 1        2         1.46010         2.00520          1.6846
# 2        3         1.42610         1.88010          1.6505
# 3        4         1.36930         1.77400          1.6233
# 4        5         1.32460         1.69300          1.5849
# ..     ...             ...             ...             ...
# 145    146         0.68180         0.42965          1.0623
# 146    147         0.68045         0.43079          1.0679
# 147    148         0.67322         0.42248          1.0643
# 148    149         0.67242         0.42049          1.0618
# 149    150         0.66601         0.41455          1.0568
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.62787            0.27104           0.29997
# 1                 0.77176            0.29847           0.34776
# 2                 0.47636            0.38411           0.36664
# ...

# %%
df = pd.read_csv('./runs/detect/Normal/results.csv')
df.columns = ['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss', "", "", ""]
df = df[['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss']]
df
# Out:
#      epoch  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1         1.41150         2.04140          1.6029
# 1        2         1.38120         1.72210          1.5909
# 2        3         1.36650         1.66050          1.5700
# 3        4         1.31720         1.58270          1.5557
# 4        5         1.26740         1.51130          1.5162
# ..     ...             ...             ...             ...
# 145    146         0.64812         0.38407          1.0368
# 146    147         0.64626         0.37992          1.0404
# 147    148         0.64639         0.37972          1.0411
# 148    149         0.63903         0.37224          1.0332
# 149    150         0.64049         0.37527          1.0328
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.80318            0.43703           0.45699
# 1                 0.80458            0.48081           0.53546
# 2                 0.85740            0.47131           0.51724
# ...

# %%
df_haar = pd.read_csv('./runs/detect/Haar/results.csv')
df_haar.columns = ['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss', "", "", ""]
df_haar = df_haar[['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss']]
df_haar
# Out:
#      epoch  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1         1.50880         2.35390          1.7305
# 1        2         1.46010         2.00520          1.6846
# 2        3         1.42610         1.88010          1.6505
# 3        4         1.36930         1.77400          1.6233
# 4        5         1.32460         1.69300          1.5849
# ..     ...             ...             ...             ...
# 145    146         0.68180         0.42965          1.0623
# 146    147         0.68045         0.43079          1.0679
# 147    148         0.67322         0.42248          1.0643
# 148    149         0.67242         0.42049          1.0618
# 149    150         0.66601         0.41455          1.0568
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.62787            0.27104           0.29997
# 1                 0.77176            0.29847           0.34776
# 2                 0.47636            0.38411           0.36664
# ...

# %%
df_sym = pd.read_csv('./runs/detect/Symlet/results.csv')
df_sym.columns = ['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss', "", "", ""]
df_sym = df_sym[['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss']]
df_sym = df_sym.iloc[:150, :]
df_sym
# Out:
#      epoch  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1         1.54680         2.38280          1.7566
# 1        2         1.51300         2.08070          1.7249
# 2        3         1.48200         1.96880          1.6949
# 3        4         1.41930         1.85730          1.6543
# 4        5         1.38610         1.79160          1.6258
# ..     ...             ...             ...             ...
# 145    146         0.71805         0.47314          1.0868
# 146    147         0.71425         0.47525          1.0958
# 147    148         0.70661         0.46682          1.0872
# 148    149         0.70643         0.46076          1.0845
# 149    150         0.69920         0.45614          1.0794
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.78132            0.20571           0.17929
# 1                 0.77742            0.28132           0.30674
# 2                 0.40451            0.24796           0.27248
# ...

# %%
df_compress = pd.read_csv('./runs/detect/Normal_Compressed/results.csv')
df_compress.columns = ['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss', "", "", ""]
df_compress = df_compress[['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss']]
df_compress = df_compress.iloc[:150, :]
df_compress
# Out:
#      epoch  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1         1.41110         2.09740          1.6076
# 1        2         1.40520         1.76510          1.5992
# 2        3         1.38440         1.70070          1.5759
# 3        4         1.32680         1.64250          1.5615
# 4        5         1.30280         1.56300          1.5339
# ..     ...             ...             ...             ...
# 145    146         0.65231         0.38659          1.0437
# 146    147         0.65561         0.39227          1.0471
# 147    148         0.64751         0.37877          1.0383
# 148    149         0.64834         0.38454          1.0414
# 149    150         0.64189         0.38268          1.0424
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.38545            0.34374           0.31042
# 1                 0.61546            0.45965           0.49017
# 2                 0.75261            0.41709           0.46943
# ...

# %%
df_haar_compress = pd.read_csv('./runs/detect/Haar_Compressed/results.csv')
df_haar_compress.columns = ['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss', "", "", ""]
df_haar_compress = df_haar_compress[['epoch', 'train/box_loss',
       'train/cls_loss', 'train/dfl_loss',
       'metrics/precision(B)', 'metrics/recall(B)',
       'metrics/mAP50(B)', 'metrics/mAP50-95(B)',
       'val/box_loss', 'val/cls_loss',
       'val/dfl_loss']]
df_haar_compress = df_haar_compress.iloc[:150, :]
df_haar_compress
# Out:
#      epoch  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1         1.51900         2.33410          1.7047
# 1        2         1.46830         2.02100          1.6758
# 2        3         1.43050         1.92080          1.6646
# 3        4         1.39660         1.82030          1.6375
# 4        5         1.33540         1.74230          1.5975
# ..     ...             ...             ...             ...
# 145    146         0.69493         0.43519          1.0692
# 146    147         0.68795         0.43722          1.0751
# 147    148         0.67559         0.43093          1.0655
# 148    149         0.67315         0.42805          1.0636
# 149    150         0.67351         0.42472          1.0610
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.58089            0.25184           0.28153
# 1                 0.63004            0.30182           0.33384
# 2                 0.50789            0.30696           0.36576
# ...

# %%
plt.figure(figsize=(12, 8))

# Plotting with different line styles, markers, and colors
plt.plot(df[["train/cls_loss"]], label="No model", linestyle='-', color="purple")
plt.plot(df_db[["train/cls_loss"]], label="Daubechies", linestyle='-', color="blue")
plt.plot(df_haar[["train/cls_loss"]], label="Haar", linestyle='-', color="green")
plt.plot(df_sym[["train/cls_loss"]], label="Symlet", linestyle='-', color="red")
plt.plot(df_compress[["train/cls_loss"]], label="No model Compressed", linestyle='-', color="orange")
plt.plot(df_haar_compress[["train/cls_loss"]], label="Haar Compressed", linestyle='-', color="yellow")

# Adding grid and adjusting legend
plt.grid(True)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Categorical Cross-Entropy Loss")
plt.legend(loc="upper right")

plt.show()

# %%
plt.figure(figsize=(16,8))

plt.plot(df[["metrics/precision(B)"]], label="No model", linestyle='-', color="purple")
plt.plot(df_db[["metrics/precision(B)"]], label="Daubechies", linestyle='-', color="blue")
plt.plot(df_haar[["metrics/precision(B)"]], label="Haar", linestyle='-', color="green")
plt.plot(df_sym[["metrics/precision(B)"]], label="Symlet", linestyle='-', color="red")
plt.plot(df_compress[["metrics/precision(B)"]], label="No model Compressed", linestyle='-', color="orange")
plt.plot(df_haar_compress[["metrics/precision(B)"]], label="Haar Compressed", linestyle='-', color="yellow")


plt.grid(True)
plt.xlabel("Epochs")
plt.ylabel("Percentual")
plt.title("Precision")
plt.legend(loc="lower right")

plt.show()

# %%
plt.figure(figsize=(12,8))

plt.plot(df[["metrics/recall(B)"]], label="No model", linestyle='-', color="purple")
plt.plot(df_db[["metrics/recall(B)"]], label="Daubechies", linestyle='-', color="blue")
plt.plot(df_haar[["metrics/recall(B)"]], label="Haar", linestyle='-', color="green")
plt.plot(df_sym[["metrics/recall(B)"]], label="Symlet", linestyle='-', color="red")
plt.plot(df_compress[["metrics/recall(B)"]], label="No model Compressed", linestyle='-', color="orange")
plt.plot(df_haar_compress[["metrics/recall(B)"]], label="Haar Compressed", linestyle='-', color="yellow")


plt.grid(True)
plt.xlabel("Epochs")
plt.ylabel("Percentual")
plt.title("Recall")
plt.legend(loc="lower right")

plt.show()

# %%
plt.figure(figsize=(12,8))

plt.plot(df[["metrics/mAP50(B)"]], label="No model", linestyle='-', color="purple")
plt.plot(df_db[["metrics/mAP50(B)"]], label="Daubechies", linestyle='-', color="blue")
plt.plot(df_haar[["metrics/mAP50(B)"]], label="Haar", linestyle='-', color="green")
plt.plot(df_sym[["metrics/mAP50(B)"]], label="Symlet", linestyle='-', color="red")
plt.plot(df_compress[["metrics/mAP50(B)"]], label="No model Compressed", linestyle='-', color="orange")
plt.plot(df_haar_compress[["metrics/mAP50(B)"]], label="Haar Compressed", linestyle='-', color="yellow")


plt.grid(True)
plt.xlabel("Epochs")
plt.ylabel("Percentual")
plt.title("mAP50")
plt.legend(loc="lower right")

plt.show()
